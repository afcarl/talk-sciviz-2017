# %% [markdown]
# # Visualizing a billion stars - eScience center - sciviz2017

# %%
1+2
# Out:
# 3

# %%
import IPython.display
IPython.display.Image(filename="logo_escience_center.png")

# %%
import vaex
import numpy as np
import matplotlib.pylab as plt
plt.style.use('bigfont')
# %matplotlib inline

# %% [markdown]
# # Step 0: reading in data
# vaex reads 'anything':
#  * `ds = vaex.open('super_fast.hdf5')`
#  * `ds = vaex.open('gadget_is_fine.hdf5')`
#  * `ds = vaex.from_pandas(df)`
#  * `ds = vaex.from_astropy_table(table)`
#  * `ds = vaex.from_ascii('takes_hours.asc')`
#  * `ds = vaex.from_csv('this_may_be_slow.csv')`
#  * `ds = vaex.from_arrays(x=x, y=y)`
#  * if everything fails, convert it using topcat

# %%
ds = vaex.open("/Users/maartenbreddels/vaex/data/nytaxi/nyc_taxi2015.hdf5")
# !ls -lh /Users/maartenbreddels/vaex/data/nytaxi/nyc_taxi2015.hdf5
# Out:
# -rw-r--r--@ 1 maartenbreddels  staff    23G Mar 29 07:32 /Users/maartenbreddels/vaex/data/nytaxi/nyc_taxi2015.hdf5

# %%
ds
# Out:
# <style>.vaex-description pre {
# 		  max-width : 450px;
# 		  white-space : nowrap;
# 		  overflow : hidden;
# 		  text-overflow: ellipsis;
# 		}
#
# 		.vex-description pre:hover {
# 		  max-width : initial;
# 		  white-space: pre;
# 		}</style>
# <div><h2>nyc_taxi2015</h2> 146,112,989 rows</div><div>path: <i>/Users/maartenbreddels/vaex/data/nytaxi/nyc_taxi2015.hdf5</i></div><div>Description: file exported by vaex, by user breddels, on date 2016-07-08 16:00:45.632305, from source /Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-01.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-02.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-03.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-04.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-05.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-06.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-07.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-08.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-09.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-10.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-11.hdf5-/Users/users/breddels/.vaex/data/nyc_taxi/yellow_tripdata_2015-12.hdf5</div><h2>Columns:</h2><table class='table-striped'><thead><tr><th>column</th><th>type</th><th>unit</th><th>description</th><th>expression</th></tr></thead><tr><td>VendorID</td><td>int64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>dropoff_dayofweek</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>dropoff_hour</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>dropoff_latitude</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>dropoff_longitude</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>extra</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>fare_amount</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>improvement_surcharge</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>mta_tax</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>passenger_count</td><td>int64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>payment_type</td><td>int64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>pickup_dayofweek</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>pickup_hour</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>pickup_latitude</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>pickup_longitude</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>tip_amount</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>tolls_amount</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>total_amount</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>tpep_dropoff_datetime</td><td>datetime64[ns]</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>tpep_pickup_datetime</td><td>datetime64[ns]</td><td></td><td ><pre></pre></td><td></td></tr><tr><td>trip_distance</td><td>float64</td><td></td><td ><pre></pre></td><td></td></tr></table><h2>Variables:</h2><table class='table-striped'><thead><tr><th>variable</th><th>type</th><th>unit</th><th>description</th><th>expression</th></tr></thead><tr><td>pi</td><td>float64</td><td>$\mathrm{}$</td><td ><pre></pre></td><td><code>3.141592653589793</code></td></tr><tr><td>e</td><td>float64</td><td>$\mathrm{}$</td><td ><pre></pre></td><td><code>2.718281828459045</code></td></tr><tr><td>km_in_au</td><td>float64</td><td>$\mathrm{}$</td><td ><pre></pre></td><td><code>149597870.7</code></td></tr><tr><td>seconds_per_year</td><td>float64</td><td>$\mathrm{}$</td><td ><pre></pre></td><td><code>31557600</code></td></tr></table><h2>Data:</h2><table class='table-striped'><thead><tr><th>#</th><th>VendorID</th><th>dropoff_dayofweek</th><th>dropoff_hour</th><th>dropoff_latitude</th><th>dropoff_longitude</th><th>extra</th><th>fare_amount</th><th>improvement_surcharge</th><th>mta_tax</th><th>passenger_count</th><th>pay ...

# %% [markdown]
# ## 0 dimensional

# %%
ds.count()
# Out:
# 146112989.0

# %%
# %%time
ds.count("pickup_latitude")
# Out:
# CPU times: user 339 ms, sys: 7.91 ms, total: 347 ms
# Wall time: 137 ms
# 143807893.0

# %%
ds.mean("pickup_latitude")
# Out:
# 40.750600575372047

# %% [markdown]
# ## 1 dimensional

# %%
ds.count(binby="pickup_latitude", limits=[40.5, 41])
# Out:
# array([  4.10000000e+01,   3.40000000e+01,   3.60000000e+01,
#          4.70000000e+01,   1.03000000e+02,   1.66000000e+02,
#          7.20000000e+01,   8.30000000e+01,   6.80000000e+01,
#          9.70000000e+01,   9.30000000e+01,   5.90000000e+01,
#          1.20000000e+02,   8.40000000e+01,   1.09000000e+02,
#          1.65000000e+02,   1.27000000e+02,   1.73000000e+02,
#          2.53000000e+02,   9.70000000e+02,   7.93000000e+02,
#          1.63700000e+03,   1.23500000e+03,   1.05600000e+03,
#          1.53800000e+03,   1.82200000e+03,   1.82600000e+03,
#          2.30300000e+03,   2.42300000e+03,   3.79700000e+03,
#          3.82400000e+03,   4.67500000e+03,   3.98900000e+03,
#          6.77900000e+03,   8.79900000e+03,   1.11450000e+04,
#          7.02189000e+05,   2.05215400e+06,   3.30456000e+05,
#          3.20690000e+04,   3.91210000e+04,   4.22370000e+04,
#          4.75130000e+04,   7.15520000e+04,   9.84480000e+04,
#          1.78168000e+05,   2.20416000e+05,   2.37613000e+05,
#          2.79931000e+05,   2.91665000e+05,   1.68988000e+05,
#          4.03061000e+05,   1.39682900e+06,   1.49183900e+06,
#          2.12504500e+06,   2.60388700e+06,   4.52890000e+06,
#          4.59496000e+06,   4.84768500e+06,   5.71410400e+06,
#          5.45410200e+06,   7.94640000e+06,   8.01032100e+06,
#          8.21417200e+06,   1.02367730e+07,   1.00830620e+07,
#          1.00750700e+07,   1.10546570e+07,   7.58952900e+06,
#          6.74080700e+06,   7.41117900e+06,   5.58180200e+06,
#          3.71976600e+06,   2.54945100e+06,   1.67434500e+06,
#          1.43710100e+06,   9.98356000e+05,   8.02345000e+05,
#          5.33212000e+05,   2.88698000e+05,   2.19143000e+05,
#          1.12678000e+05,   1.16684000e+05,   8.18810000e+04,
#          5.64770000e+04,   4.52370000e+04,   3.43510000e+04,
#          4.04870000e+04,   1.83460000e+04,   3.16450000e+04,
#          1.46820000e+04,   8.33500000e+03,   7.75400000e+03,
#          1.52500000e+04,   7.71900000e+03,   4.29300000e+03,
#          2.95900000e+03,   3.00200000e+03,   2.23300000e+03,
#          1.55100000e+03,   8.42000000e+02,   1.06400000e+03,
#          7.97000000e+02,   7.16000000e+02,   6.13000000e+02,
#          6.52000000e+02,   3.80000000e+02,   4.75000000e+02,
#          3.44000000e+02,   3.84000000e+02,   3.64000000e+02,
#          3.26000000e+02,   2.76000000e+02,   3.07000000e+02,
#          1.70000000e+02,   2.24000000e+02,   2.68000000e+02,
#          2.02000000e+02,   2.32000000e+02,   2.35000000e+02,
#          2.24000000e+02,   1.76000000e+02,   1.75000000e+02,
#          2.21000000e+02,   1.94000000e+02,   1.96000000e+02,
#          1.08000000e+02,   1.54000000e+02])

# %%
plt.plot(_)

# %% [markdown]
# ## 2 dimensional

# %%
counts2d = ds.count(binby=["pickup_longitude", "pickup_latitude"], shape=128)
print(counts2d.shape)
# Out:
# (128, 128)

# %%
plt.imshow(np.log10(counts2d+1).T, origin='lower')

# %%
limits = ds.limits(["pickup_longitude", "pickup_latitude"], "98%")
print(limits)
# Out:
# [array([-74.03799976, -73.774866  ]), array([ 40.6379567 ,  40.81379327])]

# %%
# %%time
ds.plot("pickup_longitude", "pickup_latitude", f="log1p",
        limits=limits, figsize=(10,8), shape=512)
# Out:
# CPU times: user 2.75 s, sys: 68 ms, total: 2.82 s
# Wall time: 1.07 s

# %%
# %%timeit
# counts2d = ds.count(binby=["pickup_longitude", "pickup_latitude"], shape=128, limits=limits)#, limits=[[-90, 90], [-180, 180]])

# %% [markdown]
# ## Where to pick up customers?

# %%
ds.plot("pickup_longitude", "pickup_latitude", what="mean(total_amount)",
        vmin=0, vmax=50, shape=512, figsize=(10,8), limits=limits, colormap="Greys")

# %%
# %%time
ds.minmax("trip_distance")
# Out:
# CPU times: user 659 ms, sys: 527 ms, total: 1.19 s
# Wall time: 468 ms
# array([ -4.08401244e+07,   1.98623014e+08])

# %%
ds.plot1d("trip_distance", limits=[0, 50])

# %%
ds.select("(trip_distance > 0) & (trip_distance < 40)")

# %%
# %%time
ds.plot("pickup_longitude", "pickup_latitude", what="mean(total_amount/trip_distance)",
       vmin=0, vmax=15,
       shape=512, figsize=(10,8), selection=True, limits=limits, colormap="Greys")
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in true_divide
# <string>:1: RuntimeWarning: divide by zero encountered in true_divide
# CPU times: user 6.49 s, sys: 2.13 s, total: 8.62 s
# Wall time: 3.79 s

# %% [markdown]
# ## A Billion stars in the notebook

# %%
gaia = vaex.open("ws://gaia:9000/gaia-dr1")

# %%
f"{len(gaia):,}" # python3.6 f-strings!
# Out:
# '1,142,679,769'

# %%
# %%time
ra_dec_limits = [[0, 360], [-90, 90]]
gaia.plot("ra", "dec", limits=ra_dec_limits, f="log", figsize=(10,8), shape=400)
# Out:
# CPU times: user 457 ms, sys: 67 ms, total: 524 ms
# Wall time: 3.94 s
